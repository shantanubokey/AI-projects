# %%
print('sjfbskgbs')
# Out:
# sjfbskgbs

# %%
a='anfabfabfhadddddd'

# %%
l={}
res=''
for i in a:
    l[i]=l.get(i,0)+1
    if l[i]>2 and i not in res:
        res+=i

# %%
l
# Out:
# {'a': 4, 'n': 1, 'f': 3, 'b': 2, 'h': 1, 'd': 6}

# %%
res
# Out:
# 'afd'
